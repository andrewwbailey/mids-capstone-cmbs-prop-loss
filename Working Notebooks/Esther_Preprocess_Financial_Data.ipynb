# %%
import pandas as pd
import datetime
import numpy as np

# %%
def process_excel_data(filename, nrows=None):

  df = pd.read_excel(filename, skiprows=4, nrows = nrows)

  processed_df = pd.DataFrame()

  unformatted_address = ''
  for i, row in df.iterrows():
    #print("row : " + str(i))
    if i == 0 or i % 9 == 0:
      unformatted_address = row['Unnamed: 0']
    elif (i - 1) % 9 == 0:
      sub_df = df.iloc[i:i+7, :].reset_index().drop('index', axis=1)
      sub_df.columns = sub_df.iloc[0]
      sub_df = sub_df.drop(sub_df.index[0])
      #print(sub_df)

      #quarters_list = sub_df['Quarters'].tolist()

      df_transposed = sub_df.T.reset_index()
      #print(df_transposed)

      df_transposed = df_transposed.iloc[1:]
      df_transposed = df_transposed.rename(columns={
          0: "Quarters",
          1: "Asking Rent",
          2: "Effective Rent",
          3: "Effective RPSF",
          4: "Occupancy",
          5: "Concession ($)",
          6: "Concession (%)"
      })
      
      df_transposed['Address'] = unformatted_address
      #print(df_transposed)
      processed_df = pd.concat([processed_df, df_transposed], axis=0)
      
      unformatted_address = ''
  return processed_df

# %%
def process_address_and_time(df):
  df[['Index', 'Street Address', 'City', 'State', 'Zip']] = df['Address'].str.split(', ', expand=True)
  df['Year'] = df['Quarters'].str[2:]  # extract the two digits after 'Q'
  df['Year'] = np.where(df['Year'].astype(int) > 23, '19' + df['Year'], '20' + df['Year'])
  df['Quarter'] = df['Quarters'].str[:1]
  return df

# %%
# Run for all files in a folder
# 13 files took 8s

import os

# Change the folder_path as needed
folder_path = "/content"

all_dfs = pd.DataFrame()

for file_name in os.listdir(folder_path):
  #print(file_name)
  if file_name.endswith(".xlsx"):
    sub_df = process_excel_data(file_name)
    sub_df = process_address_and_time(sub_df)
    all_dfs = pd.concat([all_dfs, sub_df], axis=0)

all_dfs
# Out:
#     Quarters Asking Rent Effective Rent Effective RPSF Occupancy  \
# 1       1Q95         NaN            NaN            NaN       NaN
# 2       2Q95         NaN            NaN            NaN       NaN
# 3       3Q95         NaN            NaN            NaN       NaN
# 4       4Q95         NaN            NaN            NaN       NaN
# 5       1Q96         NaN            NaN            NaN       NaN
# ..       ...         ...            ...            ...       ...
# 108     4Q21        2255           2255          2.102    0.9875
# 109     1Q22        2203           2203          2.053    0.9964
# 110     2Q22        2428           2428          2.263    0.9484
# 111     3Q22        2357           2357          2.197    0.9377
# 112     4Q22        2251           2251          2.098    0.9342
#
#     Concession ($) Concession (%)  \
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# 5              NaN            NaN
# ..             ...            ...
# 108              0              0
# 109              0              0
# 110              0              0
# 111              0              0
# 112              0              0
#
#                                                Address  \
# 1    [1] 10X Weston, 1343 St Tropez Cir, Weston, FL...
# 2    [1] 10X Weston, 1343 St Tropez Cir, Weston, FL...
# 3    [1] 10X Weston, 1343 St Tropez Cir, Weston, FL...
# 4    [1] 10X Weston, 1343 St Tropez Cir, Weston, FL...
# 5    [1] 10X Weston, 1343 St Tropez Cir, Weston, FL...
# ..                                                 ...
# 108  [33] Windsor Coconut Creek, 5400 Lyons Rd, Coc...
# 109  [33] Windsor Coconut Creek, 5400 Lyons Rd, Coc...
# 110  [33] Windsor Coconut Creek, 5400 Lyons Rd, Coc...
# 111  [33] Windsor Coconut Creek, 5400 Lyons Rd, Coc...
# 112  [33] Windsor Coconut Creek, 5400 Lyons Rd, Coc...
#
#                           Index      Street Address           City State  \
# 1                [1] 10X Weston  1343 St Tropez Cir         Weston    FL
# 2                [1] 10X Weston  1343 St Tropez Cir         Weston    FL
# 3                [1] 10X Weston  1343 St Tropez Cir         Weston    FL
# 4                [1] 10X Weston  1343 St Tropez Cir         Weston    FL
# 5                [1] 10X Weston  1343 St Tropez Cir         Weston    FL
# ..                          ...                 ...            ...   ...
# 108  [33] Windsor Coconut Creek       5400 Lyons Rd  Coconut Creek    FL
# 109  [33] Windsor Coconut Creek       5400 Lyons Rd  Coconut Creek    FL
# 110  [33] Windsor Coconut Creek       5400 Lyons Rd  Coconut Creek    FL
# 111  [33] Windsor Coconut Creek       5400 Lyons Rd  Coconut Creek    FL
# 112  [33] Windsor Coconut Creek       5400 Lyons Rd  Coconut Creek    FL
#
#        Zip  Year Quarter
# 1    33326  1995       1
# 2    33326  1995       2
# 3    33326  1995       3
# 4    33326  1995       4
# 5    33326  1996       1
# ..     ...   ...     ...
# 108  33073  2021       4
# 109  33073  2022       1
# 110  33073  2022       2
# 111  33073  2022       3
# 112  33073  2022       4
#
# [51994 rows x 15 columns]

# %%
# Export the formatted data out
all_dfs.to_csv("formatted_financial_data.csv", index=False)
