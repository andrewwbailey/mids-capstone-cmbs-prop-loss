# %% [markdown]
# # Andrew Bailey EDA, Data Munging, & Feature Engineering

# %%
import pandas as pd
import numpy as np
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Missing Value Analysis

# %%
# TODO: dtypes_hurricane = {"SID": string, "SEASON": ?, "NUMBER": Int64, "BASIN": string}
hurricane_data = pd.read_csv('content/ibtracs.NA.csv')

# %%
hurricane_data.head(2)

# %%
loans_data = pd.read_csv('content/loans_parse.csv')

# %%
loans_data.head(2)

# %%
cities_data = pd.read_csv('content/uscities.csv')

# %%
cities_data.head(2)

# %%
hurricane_data_count = len(hurricane_data)

hurricane_null_count = hurricane_data.isna().sum()
hurricane_null_count = hurricane_null_count.to_frame()
hurricane_null_count = hurricane_null_count.rename(columns={0: "null_count"})
hurricane_null_count = hurricane_null_count.sort_values(by='null_count',ascending=False)
hurricane_null_count['pct_null'] = (hurricane_null_count['null_count'] / hurricane_data_count) * 100
#hurricane_null_count[hurricane_null_count['pct_null'] > 0]

# %%
hurricane_null_plot = hurricane_null_count[hurricane_null_count['pct_null'] > 0]

fig_hurricane = plt.figure(figsize=(20,12))
hurricane_ax = fig_hurricane.add_subplot(3,1,1)
hurricane_ax.set_title("Missing Values in Hurricane")
hurricane_ax.grid(alpha=.3)
hurricane_ax.bar(hurricane_null_plot.index, hurricane_null_plot['pct_null'])
hurricane_ax.set_xticklabels(hurricane_null_plot.index, rotation=45)
plt.xlabel('Column Name')
plt.ylabel('Percent Missing (%)')
plt.show()

# %%
hurricane_corr_matrix = hurricane_data.corr()
sns.heatmap(hurricane_corr_matrix, annot=True)

# %%
loan_data_count = len(loans_data)

loans_null_count = loans_data.isna().sum()
loans_null_count = loans_null_count.to_frame()
loans_null_count = loans_null_count.rename(columns={0: "null_count"})
loans_null_count = loans_null_count.sort_values(by='null_count',ascending=False)
loans_null_count['pct_null'] = (loans_null_count['null_count'] / loan_data_count) * 100
#loans_null_count[loans_null_count['pct_null'] > 0]

# %%
loans_null_plot = loans_null_count[loans_null_count['pct_null'] > 0]

fig_loans = plt.figure(figsize=(20,12))
loans_ax = fig_loans.add_subplot(3,1,1)
loans_ax.set_title("Missing Values in Loans")
loans_ax.grid(alpha=.3)
loans_ax.bar(loans_null_plot.index, loans_null_plot['pct_null'])
loans_ax.set_xticklabels(loans_null_plot.index, rotation=90)
plt.xlabel('Column Name')
plt.ylabel('Percent Missing (%)')
plt.show()

# %%
loans_corr_matrix = loans_data.corr()
sns.heatmap(loans_corr_matrix, annot=False)

# %%
cities_data_count = len(cities_data)

cities_null_count = cities_data.isna().sum()
cities_null_count = cities_null_count.to_frame()
cities_null_count = cities_null_count.rename(columns={0: "null_count"})

cities_null_count = cities_null_count.sort_values(by='null_count',ascending=False)
cities_null_count['pct_null'] = (cities_null_count['null_count'] / cities_data_count) * 100
cities_null_count

cities_null_count

# %%
city_null_plot = cities_null_count[cities_null_count['pct_null'] > 0]

fig_city = plt.figure(figsize=(20,12))
city_ax = fig_city.add_subplot(3,1,1)
city_ax.set_title("Missing Values in Cities")
city_ax.grid(alpha=.3)
city_ax.bar(city_null_plot.index, loans_null_plot['pct_null'])
city_ax.set_xticklabels(city_null_plot.index, rotation=90)

# %%
cities_corr_matrix = cities_data.corr()
sns.heatmap(cities_corr_matrix, annot=True)

# %% [markdown]
# ## Joined Dataset

# %%
joined_data = pd.read_csv('content/zillow_with_expose_and_pre_exp.csv')

# %%
joined_data.head(10)

# %%
joined_data['flag_exposed'] =

# %%
join_corr_matrix = joined_data.corr()

# %%
sns.heatmap(join_corr_matrix, annot=True)

# %%
joined_data['expose_status'].unique()

# %% [markdown]
# ## Explore New Data Sets

# %%
fanniemae_dscr_time = pd.read_csv('content/fannie_mae.csv')

# %%
fanniemae_dscr_time.dtypes
# Out:
# Loan Number      int64
# Year             int64
# Year DSCR      float64
# dtype: object

# %%
fanniemae_dscr_time[fanniemae_dscr_time['Loan Number'] == 1673867584]
# Out:
# Empty DataFrame
# Columns: [Loan Number, Year, Year DSCR]
# Index: []

# %%
fanniemae_total = pd.read_csv('content/fanniemae_mf_loan_total.csv')
# Out:
# /var/folders/f2/kfq_cf6x4zz2z1q982s70wb40000gn/T/ipykernel_52541/2920474149.py:1: DtypeWarning: Columns (12,26,29,34,35,36,37,38,39,40,46,49,51,53,54,55,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   fanniemae_total = pd.read_csv('content/fanniemae_mf_loan_total.csv')

# %%
fanniemae_total.head(50)
# Out:
#     Loan Number Acquisition Date   Note Date Maturity Date at Acquisition  \
# 0        140296       2000-10-31  1985-07-16                   2001-08-10
# 1        140296       2000-10-31  1985-07-16                   2001-08-10
# 2        140296       2000-10-31  1985-07-16                   2001-08-10
# 3        140296       2000-10-31  1985-07-16                   2001-08-10
# 4        140297       2000-10-31  1985-07-18                   2001-08-10
# 5        140297       2000-10-31  1985-07-18                   2001-08-10
# 6        140297       2000-10-31  1985-07-18                   2001-08-10
# 7        140297       2000-10-31  1985-07-18                   2001-08-10
# 8    1673867584       2000-01-01  1999-11-01                   2009-12-01
# 9    1673867584       2000-01-01  1999-11-01                   2009-12-01
# 10   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 11   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 12   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 13   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 14   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 15   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 16   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 17   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 18   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 19   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 20   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 21   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 22   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 23   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 24   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 25   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 26   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 27   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 28   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 29   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 30   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 31   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 32   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 33   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 34   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 35   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 36   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 37   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 38   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 39   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 40   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 41   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 42   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 43   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 44   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 45   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 46   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 47   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 48   1673867584       2000-01-01  1999-11-01                   2009-12-01
# 49   1673867584       2000-01-01  1999-11-01                   2009-12-01
#
#    Loan Acquisition UPB   Amortization Type Interest Type Loan Product Type  \
# 0            $82,501.71                 NaN           ARM               DUS
# 1            $82,501.71                 NaN           ARM               DUS
# 2            $82,501.71                 NaN           ARM               DUS
# 3            $82,501.71                 NaN           ARM               DUS
# 4           $548,872.98                 NaN           ARM               DUS
# 5           $548,872.98                 NaN           ARM               DUS
# 6           $548,872.98                 NaN           ARM               DUS
# 7           $548,872.98                 NaN           ARM               DUS
# 8        $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 9        $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 10       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 11       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 12       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 13       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 14       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 15       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 16       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 17       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 18       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 19       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 20       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 21       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 22       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 23       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 24       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 25       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 26       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 27       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 28       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 29       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 30       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 31       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 32       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 33       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 34       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 35       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 36       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 37       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 38       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 39       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 40       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 41       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 42       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 43       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 44       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 45       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 46       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 47       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 48       $14,725,385.83  Amortizing Balloon         Fixed               DUS
# 49       $14,725,385.83  Amortizing Balloon         Fixed               DUS
#
#       Original UPB  Amortization Term  ...  Modification Indicator  \
# 0       $82,501.71                NaN  ...                       N
# 1       $82,501.71                NaN  ...                       N
# 2       $82,501.71                NaN  ...                       N
# 3       $82,501.71                NaN  ...                       N
# 4      $548,872.98                NaN  ...                       N
# 5      $548,872.98                NaN  ...                       N
# 6      $548,872.98                NaN  ...                       N
# 7      $548,872.98                NaN  ...                       N
# 8   $14,736,000.00              360.0  ...                       N
# 9   $14,736,000.00              360.0  ...                       N
# 10  $14,736,000.00              360.0  ...                       N
# 11  $14,736,000.00              360.0  ...                       N
# 12  $14,736,000.00              360.0  ...                       N
# 13  $14,736,000.00              360.0  ...                       N
# 14  $14,736,000.00              360.0  ...                       N
# 15  $14,736,000.00              360.0  ...                       N
# 16  $14,736,000.00              360.0  ...                       N
# 17  $14,736,000.00              360.0  ...                       N
# 18  $14,736,000.00              360.0  ...                       N
# 19  $14,736,000.00              360.0  ...                       N
# 20  $14,736,000.00              360.0  ...                       N
# 21  $14,736,000.00              360.0  ...                       N
# 22  $14,736,000.00              360.0  ...                       N
# 23  $14,736,000.00              360.0  ...                       N
# 24  $14,736,000.00              360.0  ...                       N
# 25  $14,736,000.00              360.0  ...                       N
# 26  $14,736,000.00              360.0  ...                       N
# 27  $14,736,000.00              360.0  ...                       N
# 28  $14,736,000.00              360.0  ...                       N
# 29  $14,736,000.00              360.0  ...                       N
# 30  $14,736,000.00              360.0  ...                       N
# 31  $14,736,000.00              360.0  ...                       N
# 32  $14,736,000.00              360.0  ...                       N
# 33  $14,736,000.00              360.0  ...                       N
# 34  $14,736,000.00              360.0  ...                       N
# 35  $14,736,000.00              360.0  ...                       N
# 36  $14,736,000.00              360.0  ...                       N
# 37  $14,736,000.00              360.0  ...                       N
# 38  $14,736,000.00              360.0  ...                       N
# 39  $14,736,000.00              360.0  ...                       N
# 40  $14,736,000.00              360.0  ...                       N
# 41  $14,736,000.00              360.0  ...                       N
# 42  $14,736,000.00              360.0  ...                       N
# 43  $14,736,000.00              360.0  ...                       N
# 44  $14,736,000.00              360.0  ...                       N
# 45  $14,736,000.00              360.0  ...                       N
# 46  $14,736,000.00              360.0  ...                       N
# 47  $14,736,000.00              360.0  ...                       N
# 48  $14,736,000.00              360.0  ...                       N
# 49  $14,736,000.00              360.0  ...                       N
#
#    Defeasance Date Prepayment Provision Prepayment Provision End Date  \
# 0              NaN                  NaN                           NaN
# 1              NaN                  NaN                           NaN
# 2              NaN                  NaN                           NaN
# 3              NaN                  NaN                           NaN
# 4              NaN                  NaN                           NaN
# 5              NaN                  NaN                           NaN
# 6              NaN                  NaN                           NaN
# 7              NaN                  NaN                           NaN
# 8              NaN       YM(114), O*(6)                           NaN
# 9              NaN       YM(114), O*(6)                           NaN
# 10             NaN       YM(114), O*(6)                           NaN
# 11             NaN       YM(114), O*(6)                           NaN
# 12             NaN       YM(114), O*(6)                           NaN
# 13             NaN       YM(114), O*(6)                           NaN
# 14             NaN       YM(114), O*(6)                           NaN
# 15             NaN       YM(114), O*(6)                           NaN
# 16             NaN       YM(114), O*(6)                           NaN
# 17             NaN       YM(114), O*(6)                           NaN
# 18             NaN       YM(114), O*(6)                           NaN
# 19             NaN       YM(114), O*(6)                           NaN
# 20             NaN       YM(114), O*(6)                           NaN
# 21             NaN       YM(114), O*(6)                           NaN
# 22             NaN       YM(114), O*(6)                           NaN
# 23             NaN       YM(114), O*(6)                           NaN
# 24             NaN       YM(114), O*(6)                           NaN
# 25             NaN       YM(114), O*(6)                           NaN
# 26             NaN       YM(114), O*(6)                           NaN
# 27             NaN       YM(114), O*(6)                           NaN
# 28             NaN       YM(114), O*(6)                           NaN
# 29             NaN       YM(114), O*(6)                           NaN
# 30             NaN       YM(114), O*(6)                           NaN
# 31             NaN       YM(114), O*(6)                           NaN
# 32             NaN       YM(114), O*(6)                           NaN
# 33             NaN       YM(114), O*(6)                           NaN
# 34             NaN       YM(114), O*(6)                           NaN
# 35             NaN       YM(114), O*(6)                           NaN
# 36             NaN       YM(114), O*(6)                           NaN
# 37             NaN       YM(114), O*(6)                           NaN
# 38             NaN       YM(114), O*(6)                           NaN
# 39             NaN       YM(114), O*(6)                           NaN
# 40             NaN       YM(114), O*(6)                           NaN
# 41             NaN       YM(114), O*(6)                           NaN
# 42             NaN       YM(114), O*(6)                           NaN
# 43             NaN       YM(114), O*(6)                           NaN
# 44             NaN       YM(114), O*(6)                           NaN
# 45             NaN       YM(114), O*(6)                           NaN
# 46             NaN       YM(114), O*(6)                           NaN
# 47             NaN       YM(114), O*(6)                           NaN
# 48             NaN       YM(114), O*(6)                           NaN
# 49             NaN       YM(114), O*(6)                           NaN
#
#     Affordable Housing Type  MCIRT Deal ID MCAS Deal ID  \
# 0                       NaN            NaN          NaN
# 1                       NaN            NaN          NaN
# 2                       NaN            NaN          NaN
# 3                       NaN            NaN          NaN
# 4                       NaN            NaN          NaN
# 5                       NaN            NaN          NaN
# 6                       NaN            NaN          NaN
# 7                       NaN            NaN          NaN
# 8                       NaN            NaN          NaN
# 9                       NaN            NaN          NaN
# 10                      NaN            NaN          NaN
# 11                      NaN            NaN          NaN
# 12                      NaN            NaN          NaN
# 13                      NaN            NaN          NaN
# 14                      NaN            NaN          NaN
# 15                      NaN            NaN          NaN
# 16                      NaN            NaN          NaN
# 17                      NaN            NaN          NaN
# 18                      NaN            NaN          NaN
# 19                      NaN            NaN          NaN
# 20                      NaN            NaN          NaN
# 21                      NaN            NaN          NaN
# 22                      NaN            NaN          NaN
# 23                      NaN            NaN          NaN
# 24                      NaN            NaN          NaN
# 25                      NaN            NaN          NaN
# 26                      NaN            NaN          NaN
# 27                      NaN            NaN          NaN
# 28                      NaN            NaN          NaN
# 29                      NaN            NaN          NaN
# 30                      NaN            NaN          NaN
# 31                      NaN            NaN          NaN
# 32                      NaN            NaN          NaN
# 33                      NaN            NaN          NaN
# 34                      NaN            NaN          NaN
# 35                      NaN            NaN          NaN
# 36                      NaN            NaN          NaN
# 37                      NaN            NaN          NaN
# 38                      NaN            NaN          NaN
# 39                      NaN            NaN          NaN
# 40                      NaN            NaN          NaN
# 41                      NaN            NaN          NaN
# 42                      NaN            NaN          NaN
# 43                      NaN            NaN          NaN
# 44                      NaN            NaN          NaN
# 45                      NaN            NaN          NaN
# 46                      NaN            NaN          NaN
# 47                      NaN            NaN          NaN
# 48                      NaN            NaN          NaN
# 49                      NaN            NaN          NaN
#
#                      DUS Prepayment Outcomes  DUS Prepayment Segments Loan Age
# 0                                        NaN                      NaN      NaN
# 1                                        NaN                      NaN      NaN
# 2                                        NaN                      NaN      NaN
# 3                                        NaN                      NaN      NaN
# 4                                        NaN                      NaN      NaN
# 5                                        NaN                      NaN      NaN
# 6                                        NaN                      NaN      NaN
# 7                                        NaN                      NaN      NaN
# 8   Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 9   Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 10  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 11  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 12  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 13  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 14  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 15  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 16  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 17  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 18  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 19  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 20  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 21  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 22  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 23  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 24  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 25  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 26  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 27  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 28  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 29  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 30  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 31  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 32  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 33  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 34  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 35  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 36  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 37  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 38  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 39  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 40  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 41  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 42  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 43  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 44  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 45  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 46  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 47  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 48  Paid Prior to Yield Maintenance End Date                 Standard     64.0
# 49  Paid Prior to Yield Maintenance End Date                 Standard     64.0
#
# [50 rows x 60 columns]

# %%
fannie_mae_sample.columns
# Out:
# Index(['Loan Number', 'Acquisition Date', 'Note Date',
#        'Maturity Date at Acquisition', 'Loan Acquisition UPB',
#        'Amortization Type', 'Interest Type', 'Loan Product Type',
#        'Original UPB', 'Amortization Term', 'Original Interest Rate',
#        'Lien Position', 'Transaction ID ', 'Issue Date',
#        'Loan Acquisition LTV', 'Underwritten DSCR', 'Underwritten DSCR Type',
#        'Original Term', 'Original I/O Term', 'I/O End Date',
#        'Loan Ever 60+ Days Delinquent', 'Loss Sharing Type',
#        'Modified Loss Sharing Percentage',
#        'Number of Properties at Acquisition',
#        'Property Acquisition Total Unit Count', 'Specific Property Type',
#        'Year Built', 'Property City', 'Property State', 'Property Zip Code',
#        'Metropolitan Statistical Area', 'Physical Occupancy %',
#        'Liquidation/Prepayment Code', 'Liquidation/Prepayment Date',
#        'Foreclosure Date', 'Credit Event Date', 'Foreclosure Value',
#        'Lifetime Net Credit Loss Amount', 'Sale Price', 'Default Amount',
#        'Credit Event Type', 'Reporting Period Date',
#        'Loan Active Property Count', 'Note Rate', 'Maturity Date - Current',
#        'UPB - Current', 'Delinquency UPB', 'Loan Payment Status',
#        'SDQ Indicator', 'Most Recent Modification Date',
#        'Modification Indicator', 'Defeasance Date', 'Prepayment Provision',
#        'Prepayment Provision End Date', 'Affordable Housing Type',
#        'MCIRT Deal ID', 'MCAS Deal ID', 'DUS Prepayment Outcomes',
#        'DUS Prepayment Segments', 'Loan Age'],
#       dtype='object')

# %%
df_joined = fanniemae_total.join(fanniemae_dscr_time, on='Loan Number', how='left', lsuffix="_dscr")

# %%
df_joined_match = df_joined[df_joined['Year DSCR'].notna()]

# %%
df_joined_match
# Out:
#    Loan Number_dscr Acquisition Date   Note Date Maturity Date at Acquisition  \
# 0            140296       2000-10-31  1985-07-16                   2001-08-10
# 1            140296       2000-10-31  1985-07-16                   2001-08-10
# 2            140296       2000-10-31  1985-07-16                   2001-08-10
# 3            140296       2000-10-31  1985-07-16                   2001-08-10
# 4            140297       2000-10-31  1985-07-18                   2001-08-10
# 5            140297       2000-10-31  1985-07-18                   2001-08-10
# 6            140297       2000-10-31  1985-07-18                   2001-08-10
# 7            140297       2000-10-31  1985-07-18                   2001-08-10
#
#   Loan Acquisition UPB Amortization Type Interest Type Loan Product Type  \
# 0           $82,501.71               NaN           ARM               DUS
# 1           $82,501.71               NaN           ARM               DUS
# 2           $82,501.71               NaN           ARM               DUS
# 3           $82,501.71               NaN           ARM               DUS
# 4          $548,872.98               NaN           ARM               DUS
# 5          $548,872.98               NaN           ARM               DUS
# 6          $548,872.98               NaN           ARM               DUS
# 7          $548,872.98               NaN           ARM               DUS
#
#   Original UPB  Amortization Term  ...  Prepayment Provision End Date  \
# 0   $82,501.71                NaN  ...                            NaN
# 1   $82,501.71                NaN  ...                            NaN
# 2   $82,501.71                NaN  ...                            NaN
# 3   $82,501.71                NaN  ...                            NaN
# 4  $548,872.98                NaN  ...                            NaN
# 5  $548,872.98                NaN  ...                            NaN
# 6  $548,872.98                NaN  ...                            NaN
# 7  $548,872.98                NaN  ...                            NaN
#
#   Affordable Housing Type MCIRT Deal ID MCAS Deal ID  DUS Prepayment Outcomes  \
# 0                     NaN           NaN          NaN                      NaN
# 1                     NaN           NaN          NaN                      NaN
# 2                     NaN           NaN          NaN                      NaN
# 3                     NaN           NaN          NaN                      NaN
# 4                     NaN           NaN          NaN                      NaN
# 5                     NaN           NaN          NaN                      NaN
# 6                     NaN           NaN          NaN                      NaN
# 7                     NaN           NaN          NaN                      NaN
#
#    DUS Prepayment Segments Loan Age   Loan Number    Year Year DSCR
# 0                      NaN      NaN  1.717471e+09  2019.0      1.56
# 1                      NaN      NaN  1.717471e+09  2019.0      1.56
# 2                      NaN      NaN  1.717471e+09  2019.0      1.56
# 3                      NaN      NaN  1.717471e+09  2019.0      1.56
# 4                      NaN      NaN  1.717471e+09  2020.0      1.58
# 5                      NaN      NaN  1.717471e+09  2020.0      1.58
# 6                      NaN      NaN  1.717471e+09  2020.0      1.58
# 7                      NaN      NaN  1.717471e+09  2020.0      1.58
#
# [8 rows x 63 columns]

# %%
fanniemae_mf_data = pd.read_csv('content/data_part1.csv')

# %%
fanniemae_mf_data.head(10)

# %%
fanniemae_mf_data.columns
